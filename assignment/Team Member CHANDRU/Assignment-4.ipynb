# %% [markdown]
# # Assignment-4

# %% [markdown]
# ## SMS SPAM Classification

# %%
#Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model,Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline

# %% [markdown]
# # Reading the dataset

# %%
df = pd.read_csv("spam.csv",encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
sns.countplot(df.v1)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
# Out:
# C:\Users\gopin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of ham and spam messages')

# %%
X = df.v2
Y = df.v1
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %% [markdown]
# # Process the data

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = pad_sequences(sequences,maxlen=max_len)
sequences_matrix
# Out:
# array([[  0,   0,   0, ...,  76,  16,  98],
#        [  0,   0,   0, ...,  34,  84,  55],
#        [  0,   0,   0, ...,  34, 200, 900],
#        ...,
#        [  0,   0,   0, ...,  12,  13,  91],
#        [  0,   0,   0, ...,   8,  43,  41],
#        [  0,   0,   0, ...,   4,  12,  48]])

# %%
tok.index_word
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'you',
#  4: 'a',
#  5: 'the',
#  6: 'u',
#  7: 'and',
#  8: 'is',
#  9: 'in',
#  10: 'me',
#  11: 'my',
#  12: 'for',
#  13: 'your',
#  14: 'it',
#  15: 'of',
#  16: 'call',
#  17: 'have',
#  18: 'on',
#  19: '2',
#  20: 'that',
#  21: 'now',
#  22: 'are',
#  23: 'so',
#  24: 'but',
#  25: 'not',
#  26: 'can',
#  27: 'at',
#  28: 'or',
#  29: 'do',
#  30: "i'm",
#  31: 'get',
#  32: 'ur',
#  33: 'will',
#  34: 'be',
#  35: 'if',
#  36: 'with',
#  37: 'just',
#  38: 'no',
#  39: 'we',
#  40: 'this',
#  41: 'gt',
#  42: 'when',
#  43: 'lt',
#  44: '4',
#  45: 'up',
#  46: 'go',
#  47: 'free',
#  48: 'all',
#  49: 'ok',
#  50: 'how',
#  51: 'out',
#  52: 'from',
#  53: 'know',
#  54: 'what',
#  55: 'then',
#  56: 'good',
#  57: 'got',
#  58: 'like',
#  59: 'was',
#  60: 'come',
#  61: 'am',
#  62: 'its',
#  63: 'only',
#  64: 'time',
#  65: 'love',
#  66: 'there',
#  67: 'day',
#  68: 'send',
#  69: 'he',
#  70: 'text',
#  71: 'want',
#  72: 'as',
#  73: 'about',
#  74: 'one',
#  75: 'need',
#  76: "i'll",
#  77: 'going',
#  78: 'txt',
#  79: 'stop',
#  80: 'home',
#  81: 'r',
#  82: 'sorry',
#  83: 'lor',
#  84: 'by',
#  85: 'still',
#  86: 'da',
#  87: 'today',
#  88: 'see',
#  89: 'our',
#  90: 'n',
#  91: 'mobile',
#  92: 'back',
#  93: 'dont',
#  94: 'k',
#  95: 'tell',
#  96: 'reply',
#  97: 'take',
#  98: 'later',
#  99: 'she',
#  100: "don't",
#  101: 'hi',
#  102: 'they',
#  103: 'any',
#  104: 'please',
#  105: 'pls',
#  106: 'think',
#  107: 'been',
#  108: 'her',
#  109: 'dear',
#  110: 'did',
#  111: 'new',
#  112: 'ì',
#  113: 'week',
#  114: 'hey',
#  115: 'some',
#  116: 'msg',
#  117: '1',
#  118: 'here',
#  119: 'night',
#  120: 'him',
#  121: 'oh',
#  122: 'phone',
#  123: 'an',
#  124: 'claim',
#  125: 'more',
#  126: 'well',
#  127: 'who',
#  128: 'yes',
#  129: 'hope',
#  130: 'had',
#  131: 'too',
#  132: 'much',
#  133: 'great',
#  134: 'make',
#  135: 'has',
#  136: 'work',
#  137: 'c',
#  138: 'where',
#  139: "it's",
#  140: 'wat',
#  141: 'should',
#  142: 'e',
#  143: 'www',
#  144: 'way',
#  145: 'give',
#  146: 'happy',
#  147: 'tomorrow',
#  148: 'said',
#  149: 'already',
#  150: 'doing',
#  151: 'message',
#  152: 'd',
#  153: 'say',
#  154: 'prize',
#  155: 'yeah',
#  156: 'number',
#  157: 'after',
#  158: 'why',
#  159: 'them',
#  160: 'right',
#  161: 'meet',
#  162: 'im',
#  163: 'really',
#  164: 'ask',
#  165: 'life',
#  166: 'last',
#  167: '3',
#  168: 'amp',
#  169: 'anything',
#  170: 'miss',
#  171: 'cos',
#  172: 't',
#  173: 'every',
#  174: 'find',
#  175: 'morning',
#  176: 'thanks',
#  177: 'very',
#  178: 'babe',
#  179: 'cash',
#  180: 'let',
#  181: 'also',
#  182: '150p',
#  183: 'wait',
#  184: 'lol',
#  185: 'something',
#  186: 'win',
#  187: 'buy',
#  188: 'would',
#  189: 'com',
#  190: 'sure',
#  191: 'b',
#  192: 'contact',
#  193: 'care',
#  194: 'nokia',
#  195: 'won',
#  196: 's',
#  197: '5',
#  198: 'min',
#  199: "i've",
#  200: 'around',
#  201: 'were',
#  202: 'over',
#  203: 'again',
#  204: 'even',
#  205: 'off',
#  206: 'urgent',
#  207: 'feel',
#  208: 'pick',
#  209: 'first',
#  210: 'gonna',
#  211: 'cant',
#  212: 'someone',
#  213: 'which',
#  214: 'uk',
#  215: 'us',
#  216: 'went',
#  217: 'place',
#  218: 'tonight',
#  219: 'sent',
#  220: 'per',
#  221: 'soon',
#  222: 'ya',
#  223: 'always',
#  224: 'keep',
#  225: 'before',
#  226: "can't",
#  227: 'thing',
#  228: 'hello',
#  229: 'nice',
#  230: 'sms',
#  231: 'tone',
#  232: 'things',
#  233: 'late',
#  234: 'his',
#  235: 'x',
#  236: 'service',
#  237: 'money',
#  238: 'friends',
#  239: 'next',
#  240: 'could',
#  241: 'many',
#  242: 'waiting',
#  243: 'chat',
#  244: "that's",
#  245: 'wan',
#  246: 'co',
#  247: 'coming',
#  248: 'sleep',
#  249: 'help',
#  250: 'down',
#  251: 'v',
#  252: "you're",
#  253: '50',
#  254: 'leave',
#  255: 'customer',
#  256: 'try',
#  257: 'ìï',
#  258: 'done',
#  259: 'dun',
#  260: 'special',
#  261: '16',
#  262: 'gud',
#  263: 'haha',
#  264: 'told',
#  265: 'wish',
#  266: 'lunch',
#  267: 'friend',
#  268: 'thought',
#  269: 'getting',
#  270: 'other',
#  271: 'heart',
#  272: 'year',
#  273: 'use',
#  274: 'fine',
#  275: 'smile',
#  276: 'house',
#  277: 'name',
#  278: 'yet',
#  279: '6',
#  280: 'thk',
#  281: 'man',
#  282: 'people',
#  283: 'same',
#  284: 'better',
#  285: '18',
#  286: 'job',
#  287: 'cs',
#  288: '7',
#  289: 'days',
#  290: 'mins',
#  291: 'talk',
#  292: 'holiday',
#  293: 'car',
#  294: 'thats',
#  295: 'being',
#  296: 'yup',
#  297: "didn't",
#  298: 'finish',
#  299: 'ill',
#  300: 'meeting',
#  301: 'never',
#  302: 'stuff',
#  303: 'bit',
#  304: 'y',
#  305: 'cool',
#  306: 'few',
#  307: 'guaranteed',
#  308: 'class',
#  309: 'having',
#  310: 'long',
#  311: 'problem',
#  312: 'may',
#  313: 'lar',
#  314: 'wk',
#  315: 'guess',
#  316: 'best',
#  317: 'ready',
#  318: 'end',
#  319: 'dat',
#  320: 'draw',
#  321: 'live',
#  322: 'person',
#  323: 'eat',
#  324: 'play',
#  325: 'real',
#  326: 'camera',
#  327: 'enjoy',
#  328: 'wanna',
#  329: 'yo',
#  330: 'sweet',
#  331: 'god',
#  332: 'than',
#  333: 'sir',
#  334: 'line',
#  335: 'account',
#  336: 'liao',
#  337: 'trying',
#  338: 'lot',
#  339: '1st',
#  340: 'mind',
#  341: 'receive',
#  342: 'world',
#  343: 'watch',
#  344: 'big',
#  345: 'month',
#  346: 'jus',
#  347: 'part',
#  348: 'latest',
#  349: 'chance',
#  350: 'room',
#  351: 'wont',
#  352: 'awarded',
#  353: 'into',
#  354: 'word',
#  355: 'check',
#  356: 'quite',
#  357: 'half',
#  358: 'because',
#  359: 'remember',
#  360: 'dinner',
#  361: 'office',
#  362: 'offer',
#  363: 'pa',
#  364: 'shall',
#  365: 'ah',
#  366: 'nothing',
#  367: 'start',
#  368: 'rate',
#  369: 'little',
#  370: 'luv',
#  371: 'plan',
#  372: 'birthday',
#  373: 'forgot',
#  374: 'shit',
#  375: 'dunno',
#  376: 'easy',
#  377: 'might',
#  378: 'video',
#  379: 'shows',
#  380: 'watching',
#  381: 'two',
#  382: 'does',
#  383: 'tv',
#  384: 'hear',
#  385: 'guys',
#  386: 'thanx',
#  387: 'box',
#  388: 'ringtone',
#  389: 'å£1',
#  390: 'probably',
#  391: 'bad',
#  392: 'called',
#  393: 'left',
#  394: 'kiss',
#  395: 'xxx',
#  396: 'cost',
#  397: 'early',
#  398: 'leh',
#  399: 'bed',
#  400: 'sat',
#  401: 'den',
#  402: 'landline',
#  403: 'another',
#  404: 'wife',
#  405: 'baby',
#  406: 'hour',
#  407: 'apply',
#  408: 'aight',
#  409: 'bt',
#  410: 'princess',
#  411: 'bus',
#  412: '10',
#  413: 'wif',
#  414: "how's",
#  415: '9',
#  416: 'put',
#  417: "he's",
#  418: 'town',
#  419: 'until',
#  420: '2nd',
#  421: 'without',
#  422: 'minutes',
#  423: 'll',
#  424: 'po',
#  425: '150ppm',
#  426: 'looking',
#  427: 'once',
#  428: 'reach',
#  429: 'speak',
#  430: 'wanted',
#  431: 'those',
#  432: 'code',
#  433: 'dad',
#  434: 'working',
#  435: 'everything',
#  436: 'made',
#  437: 'selected',
#  438: 'å£1000',
#  439: 'de',
#  440: 'tmr',
#  441: 'while',
#  442: 'girl',
#  443: 'face',
#  444: 'wake',
#  445: 'means',
#  446: 'dis',
#  447: 'shopping',
#  448: 'true',
#  449: 'evening',
#  450: 'fun',
#  451: 'look',
#  452: 'thank',
#  453: 'wot',
#  454: 'ever',
#  455: 'details',
#  456: 'since',
#  457: 'asked',
#  458: 'goes',
#  459: 'missing',
#  460: 'pay',
#  461: 'enough',
#  462: 'calls',
#  463: 'xmas',
#  464: 'pain',
#  465: 'anyway',
#  466: 'yesterday',
#  467: 'between',
#  468: 'must',
#  469: 'g',
#  470: 'afternoon',
#  471: 'able',
#  472: 'didnt',
#  473: '8',
#  474: 'maybe',
#  475: 'school',
#  476: '500',
#  477: 'messages',
#  478: 'came',
#  479: 'hair',
#  480: 'orange',
#  481: 'sexy',
#  482: 'mob',
#  483: 'important',
#  484: 'abt',
#  485: 'award',
#  486: 'network',
#  487: '000',
#  488: 'missed',
#  489: 'most',
#  490: 'collection',
#  491: 'fuck',
#  492: 'juz',
#  493: 're',
#  494: 'm',
#  495: 'ard',
#  496: 'worry',
#  497: 'weekly',
#  498: 'decimal',
#  499: 'online',
#  500: 'entry',
#  501: 'saw',
#  502: 'plus',
#  503: 'texts',
#  504: 'says',
#  505: 'actually',
#  506: 'away',
#  507: 'hav',
#  508: 'game',
#  509: 'years',
#  510: 'mail',
#  511: 'music',
#  512: 'collect',
#  513: 'bring',
#  514: 'stay',
#  515: "''",
#  516: 'till',
#  517: 'attempt',
#  518: 'okay',
#  519: 'join',
#  520: "there's",
#  521: 'lei',
#  522: 'oso',
#  523: 'update',
#  524: 'makes',
#  525: 'though',
#  526: 'plz',
#  527: "we're",
#  528: 'wid',
#  529: 'top',
#  530: 'wen',
#  531: 'saying',
#  532: 'id',
#  533: 'words',
#  534: 'order',
#  535: 'boy',
#  536: 'price',
#  537: 'driving',
#  538: 'dude',
#  539: 'yours',
#  540: 'til',
#  541: 'tones',
#  542: 'weekend',
#  543: '10p',
#  544: 'national',
#  545: 'comes',
#  546: 'coz',
#  547: 'finished',
#  548: 'nite',
#  549: 'friendship',
#  550: "won't",
#  551: 'games',
#  552: 'hot',
#  553: 'havent',
#  554: 'alright',
#  555: 'gift',
#  556: 'sad',
#  557: 'bored',
#  558: 'mean',
#  559: 'book',
#  560: 'haf',
#  561: 'sleeping',
#  562: 'times',
#  563: 'beautiful',
#  564: 'valid',
#  565: 'show',
#  566: 'lose',
#  567: 'dreams',
#  568: 'making',
#  569: 'double',
#  570: 'else',
#  571: 'guy',
#  572: "what's",
#  573: 'tried',
#  574: 'hurt',
#  575: 'colour',
#  576: 'shop',
#  577: 'club',
#  578: 'address',
#  579: 'huh',
#  580: 'net',
#  581: 'vouchers',
#  582: 'forget',
#  583: 'wants',
#  584: 'ring',
#  585: "we'll",
#  586: 'believe',
#  587: 'delivery',
#  588: 'answer',
#  589: 'walk',
#  590: 'pounds',
#  591: 'yourself',
#  592: 'charge',
#  593: 'aft',
#  594: 'chikku',
#  595: 'pic',
#  596: 'calling',
#  597: 'goin',
#  598: "she's",
#  599: 'started',
#  600: 'å£5000',
#  601: 'await',
#  602: 'sae',
#  603: 'pm',
#  604: 'thinking',
#  605: 'brother',
#  606: 'news',
#  607: 'points',
#  608: 'smiling',
#  609: 'set',
#  610: 'together',
#  611: 'auction',
#  612: 'movie',
#  613: 'touch',
#  614: 'å£100',
#  615: 'change',
#  616: 'test',
#  617: 'mine',
#  618: 'row',
#  619: 'awesome',
#  620: 'these',
#  621: 'http',
#  622: 'worth',
#  623: 'date',
#  624: '8007',
#  625: 'both',
#  626: 'busy',
#  627: '86688',
#  628: 'bonus',
#  629: 'close',
#  630: 'drive',
#  631: "haven't",
#  632: 'simple',
#  633: 'cause',
#  634: 'hours',
#  635: 'family',
#  636: 'drink',
#  637: 'w',
#  638: 'story',
#  639: 'eve',
#  640: 'sis',
#  641: 'food',
#  642: 'happen',
#  643: 'wil',
#  644: 'ha',
#  645: 'took',
#  646: 'run',
#  647: 'break',
#  648: 'anyone',
#  649: 'trip',
#  650: 'everyone',
#  651: 'question',
#  652: 'gone',
#  653: 'tho',
#  654: 'feeling',
#  655: 'minute',
#  656: 'type',
#  657: 'noe',
#  658: 'rite',
#  659: 'don',
#  660: 'prob',
#  661: 'private',
#  662: 'todays',
#  663: 'okie',
#  664: 'post',
#  665: 'å£500',
#  666: 'voucher',
#  667: 'services',
#  668: 'dating',
#  669: 'tomo',
#  670: 'å£3',
#  671: 'whatever',
#  672: 'info',
#  673: 'congrats',
#  674: 'old',
#  675: 'poly',
#  676: 'either',
#  677: 'sister',
#  678: 'smth',
#  679: 'kind',
#  680: 'final',
#  681: 'unsubscribe',
#  682: 'taking',
#  683: 'email',
#  684: 'smoke',
#  685: 'card',
#  686: 'sch',
#  687: 'girls',
#  688: 'full',
#  689: '750',
#  690: 'xx',
#  691: 'takes',
#  692: 'drop',
#  693: 'goodmorning',
#  694: '11',
#  695: 'expires',
#  696: 'head',
#  697: 'crazy',
#  698: 'statement',
#  699: 'frm',
#  700: 'whats',
#  701: 'boytoy',
#  702: 'pics',
#  703: 'alone',
#  704: 'fri',
#  705: 'sun',
#  706: 'light',
#  707: 'ltd',
#  708: 'pobox',
#  709: 'company',
#  710: 'search',
#  711: 'choose',
#  712: 'listen',
#  713: 'opt',
#  714: 'leaving',
#  715: 'open',
#  716: 'treat',
#  717: 'neva',
#  718: 'bout',
#  719: 'found',
#  720: 'hard',
#  721: 'gd',
#  722: 'reason',
#  723: 'tot',
#  724: 'nt',
#  725: 'weeks',
#  726: 'mu',
#  727: 'loving',
#  728: '\x89û',
#  729: '100',
#  730: '08000930705',
#  731: 'lovely',
#  732: 'å£2000',
#  733: 'far',
#  734: 'savamob',
#  735: 'case',
#  736: 'lets',
#  737: 'park',
#  738: 'identifier',
#  739: '30',
#  740: 'second',
#  741: 'seeing',
#  742: 'friday',
#  743: 'bslvyl',
#  744: 'pub',
#  745: 'party',
#  746: 'felt',
#  747: 'winner',
#  748: 'march',
#  749: 'sea',
#  750: 'oredi',
#  751: 'needs',
#  752: 'credit',
#  753: 'offers',
#  754: "c's",
#  755: 'gr8',
#  756: 'mobileupd8',
#  757: 'wonderful',
#  758: 'secret',
#  759: 'sunday',
#  760: 'hows',
#  761: 'fone',
#  762: 'thinks',
#  763: 'mates',
#  764: 'lesson',
#  765: 'pretty',
#  766: 'land',
#  767: 'welcome',
#  768: 'bank',
#  769: 'suite342',
#  770: '2lands',
#  771: 'carlos',
#  772: 'msgs',
#  773: 'unlimited',
#  774: 'fast',
#  775: 'college',
#  776: 'visit',
#  777: 'tel',
#  778: 'nope',
#  779: 'knw',
#  780: 'project',
#  781: 'camcorder',
#  782: 'frnd',
#  783: 'each',
#  784: 'congratulations',
#  785: 'enter',
#  786: 'hee',
#  787: 'outside',
#  788: 'whole',
#  789: 'their',
#  790: "doesn't",
#  791: 'india',
#  792: 'hit',
#  793: 'tc',
#  794: 'b4',
#  795: 'ni8',
#  796: 'via',
#  797: 'ugh',
#  798: 'happened',
#  799: 'download',
#  800: 'luck',
#  801: 'press',
#  802: 'earlier',
#  803: 'john',
#  804: 'å£250',
#  805: 'yr',
#  806: 'father',
#  807: 'hmm',
#  808: 'na',
#  809: 'ass',
#  810: 'freemsg',
#  811: 'hand',
#  812: 'content',
#  813: 'ten',
#  814: 'st',
#  815: 'used',
#  816: 'saturday',
#  817: 'etc',
#  818: 'reveal',
#  819: 'talking',
#  820: 'understand',
#  821: 'lots',
#  822: "you'll",
#  823: "'",
#  824: 'currently',
#  825: 'sounds',
#  826: 'wrong',
#  827: 'cut',
#  828: 'mayb',
#  829: 'mr',
#  830: 'anytime',
#  831: '12hrs',
#  832: 'darlin',
#  833: 'angry',
#  834: 'mah',
#  835: 'difficult',
#  836: 'fucking',
#  837: 'cum',
#  838: 'gotta',
#  839: 'yar',
#  840: 'tired',
#  841: 'chennai',
#  842: 'direct',
#  843: '03',
#  844: 'wow',
#  845: 'reading',
#  846: 'red',
#  847: 'wine',
#  848: 'confirm',
#  849: 'met',
#  850: 'stupid',
#  851: 'fancy',
#  852: "i'd",
#  853: 'read',
#  854: 'jay',
#  855: 'player',
#  856: 'gym',
#  857: 'o',
#  858: 'uncle',
#  859: 'sex',
#  860: 'dnt',
#  861: 'within',
#  862: 'side',
#  863: 'hold',
#  864: 'hmmm',
#  865: 'whenever',
#  866: 'phones',
#  867: '08000839402',
#  868: 'mom',
#  869: 'course',
#  870: '12',
#  871: 'motorola',
#  872: 'questions',
#  873: 'comp',
#  874: 'darren',
#  875: 'mate',
#  876: 'parents',
#  877: 'available',
#  878: 'fr',
#  879: 'å£350',
#  880: 'valued',
#  881: 'reward',
#  882: 'knew',
#  883: 'lost',
#  884: 'die',
#  885: 'christmas',
#  886: 'wonder',
#  887: 'supposed',
#  888: 'meant',
#  889: 'f',
#  890: 'song',
#  891: 'seen',
#  892: 'support',
#  893: 'quiz',
#  894: 'remove',
#  895: 'laptop',
#  896: 'dogging',
#  897: 'finally',
#  898: 'rs',
#  899: 'police',
#  900: 'usf',
#  901: 'å£2',
#  902: 'frnds',
#  903: 'p',
#  904: 'orchard',
#  905: 'myself',
#  906: 'del',
#  907: 'lovable',
#  908: 'sort',
#  909: 'save',
#  910: 'point',
#  911: 'own',
#  912: 'film',
#  913: 'computer',
#  914: 'store',
#  915: '2003',
#  916: '800',
#  917: 'area',
#  918: 'grins',
#  919: 'checking',
#  920: 'wkly',
#  921: '87066',
#  922: 'eh',
#  923: 'ipod',
#  924: 'askd',
#  925: 'least',
#  926: 'truth',
#  927: 'feels',
#  928: 'bcoz',
#  929: 'worried',
#  930: 'comin',
#  931: 'wit',
#  932: 'ago',
#  933: 'laugh',
#  934: 'mum',
#  935: 'information',
#  936: 'gas',
#  937: 'entered',
#  938: 'invited',
#  939: 'charged',
#  940: 'sending',
#  941: 'admirer',
#  942: 'txting',
#  943: 'lucky',
#  944: 'log',
#  945: 'couple',
#  946: 'correct',
#  947: 'rock',
#  948: 'snow',
#  949: 'callertune',
#  950: 'rest',
#  951: 'sub',
#  952: 'tickets',
#  953: 'th',
#  954: '0800',
#  955: 'happiness',
#  956: 'abiola',
#  957: 'picking',
#  958: 'crave',
#  959: 'ans',
#  960: '20',
#  961: 'muz',
#  962: 'balance',
#  963: 'caller',
#  964: 'small',
#  965: 'discount',
#  966: 'em',
#  967: 'bath',
#  968: 'ends',
#  969: 'empty',
#  970: 'decided',
#  971: 'hg',
#  972: 'woke',
#  973: 'paper',
#  974: 'glad',
#  975: 'safe',
#  976: 'merry',
#  977: 'poor',
#  978: 'ge',
#  979: 'ac',
#  980: '00',
#  981: 'hmv',
#  982: 'asking',
#  983: 'rakhesh',
#  984: 'access',
#  985: 'months',
#  986: 'disturb',
#  987: 'somewhere',
#  988: 'moment',
#  989: 'swing',
#  990: 'different',
#  991: 'un',
#  992: 'redeemed',
#  993: '04',
#  994: 'through',
#  995: 'eyes',
#  996: 'age',
#  997: 'txts',
#  998: 'sound',
#  999: 'move',
#  1000: 'goodnight',
#  ...}

# %% [markdown]
# # Creating model and Adding the layers

# %%
TOT_SIZE = len(tok.word_index)+1
lstm_model = Sequential()
lstm_model.add(Embedding(TOT_SIZE, 32, input_length=max_len))
lstm_model.add(LSTM(100))
lstm_model.add(Dropout(0.4))
lstm_model.add(Dense(20, activation="relu"))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(1, activation = "sigmoid"))

# %%
lstm_model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 32)           261824
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 20)                2020
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 317,065
# Trainable params: 317,065
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Fit the model

# %%
lstm_model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
          validation_split=0.2,
          workers=10,
           callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/10
# 30/30 [==============================] - 34s 760ms/step - loss: 0.4881 - accuracy: 0.8369 - val_loss: 0.3310 - val_accuracy: 0.8671
# Epoch 2/10
# 30/30 [==============================] - 25s 837ms/step - loss: 0.2560 - accuracy: 0.9261 - val_loss: 0.1262 - val_accuracy: 0.9715

# %% [markdown]
# # Save the model

# %%
lstm_model.save('sms.h5')

# %% [markdown]
# # Test the model

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)

# %%
acc = lstm_model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 27/27 [==============================] - 2s 86ms/step - loss: 0.1264 - accuracy: 0.9749

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc[0],acc[1]))
# Out:
# Test set
#   Loss: 0.126
#   Accuracy: 0.975
